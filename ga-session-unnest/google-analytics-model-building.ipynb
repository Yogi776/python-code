# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
# %matplotlib inline

# %%
df_train = pd.read_csv("sample.csv")

# %%
df_train.tail()
# Out:
#    channelGrouping      date  \
# 15  Organic Search  20160902
# 16  Organic Search  20160902
# 17  Organic Search  20160902
# 18  Organic Search  20160902
# 19  Organic Search  20160902
#
#                                                device  fullVisitorId  \
# 15  {"browser": "Chrome", "browserVersion": "not a...   9.640000e+18
# 16  {"browser": "Chrome", "browserVersion": "not a...   9.880000e+18
# 17  {"browser": "Internet Explorer", "browserVersi...   2.220000e+18
# 18  {"browser": "Chrome", "browserVersion": "not a...   9.670000e+18
# 19  {"browser": "Chrome", "browserVersion": "not a...   3.700000e+18
#
#                                            geoNetwork  \
# 15  {"continent": "Asia", "subContinent": "Eastern...
# 16  {"continent": "Europe", "subContinent": "Weste...
# 17  {"continent": "Europe", "subContinent": "Weste...
# 18  {"continent": "Asia", "subContinent": "Southea...
# 19  {"continent": "Americas", "subContinent": "Sou...
#
#                          sessionId  socialEngagementType  \
# 15  9638207207743070032_1472824614  Not Socially Engaged
# 16  9876750586615598787_1472801099  Not Socially Engaged
# 17  2222266935962032743_1472826820  Not Socially Engaged
# 18  9674781571160116268_1472804607  Not Socially Engaged
# 19  3696906537737368442_1472856874  Not Socially Engaged
#
#                                                totals  \
# 15  {"visits": "1", "hits": "1", "pageviews": "1",...
# 16  {"visits": "1", "hits": "1", "pageviews": "1",...
# 17  {"visits": "1", "hits": "1", "pageviews": "1",...
# 18  {"visits": "1", "hits": "1", "pageviews": "1",...
# 19  {"visits": "1", "hits": "1", "pageviews": "1",...
#
#                                         trafficSource     visitId  \
# 15  {"campaign": "(not set)", "source": "baidu", "...  1472824614
# 16  {"campaign": "(not set)", "source": "google", ...  1472801099
# 17  {"campaign": "(not set)", "source": "google", ...  1472826820
# 18  {"campaign": "(not set)", "source": "google", ...  1472804607
# 19  {"campaign": "(not set)", "source": "google", ...  1472856874
#
#     visitNumber  visitStartTime
# 15            1      1472824614
# 16            1      1472801099
# 17            1      1472826820
# 18            1      1472804607
# 19            1      1472856874

# %%
#convert json columns

import os
import json
from pandas.io.json import json_normalize

def load_df(csv_path='smple.csv', nrows=None):
    JSON_COLUMNS = ['device', 'geoNetwork', 'totals', 'trafficSource']
    
    df = pd.read_csv(csv_path, 
                     converters={column: json.loads for column in JSON_COLUMNS}, 
                     dtype={'fullVisitorId': 'str'}, # Important!!
                     nrows=nrows)
    
    for column in JSON_COLUMNS:
        column_as_df = json_normalize(df[column])
        column_as_df.columns = [f"{column}.{subcolumn}" for subcolumn in column_as_df.columns]
        df = df.drop(column, axis=1).merge(column_as_df, right_index=True, left_index=True)
    print(f"Loaded {os.path.basename(csv_path)}. Shape: {df.shape}")
    return df

# %%
train_df = load_df('sample.csv')
# Out:
# Loaded sample.csv. Shape: (20, 46)
# /home/yogesh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   app.launch_new_instance()

# %%
train_df
# Out:
#    channelGrouping      date fullVisitorId                       sessionId  \
# 0   Organic Search  20160902      1.13E+18  1131660440785968503_1472830385
# 1   Organic Search  20160902      3.77E+17   377306020877927890_1472880147
# 2   Organic Search  20160902      3.90E+18  3895546263509774583_1472865386
# 3   Organic Search  20160902      4.76E+18  4763447161404445595_1472881213
# 4   Organic Search  20160902      2.73E+16    27294437909732085_1472822600
# 5   Organic Search  20160902      2.94E+18  2938943183656635653_1472807194
# 6   Organic Search  20160902      1.91E+18  1905672039242460897_1472817241
# 7   Organic Search  20160902      5.37E+17   537222803633850821_1472812602
# 8   Organic Search  20160902      4.45E+18  4445454811831400414_1472805784
# 9   Organic Search  20160902      9.50E+18  9499785259412240342_1472812272
# 10  Organic Search  20160902      5.23E+17  0523069750702990437_1472834967
# 11  Organic Search  20160902      9.82E+17   982320996976275749_1472849434
# 12  Organic Search  20160902      3.58E+17   357659889600827884_1472839882
# 13  Organic Search  20160902      1.44E+18  1438082600262726746_1472803483
# 14  Organic Search  20160902      3.53E+18  3531015320757710684_1472868337
# 15  Organic Search  20160902      9.64E+18  9638207207743070032_1472824614
# 16  Organic Search  20160902      9.88E+18  9876750586615598787_1472801099
# 17  Organic Search  20160902      2.22E+18  2222266935962032743_1472826820
# 18  Organic Search  20160902      9.67E+18  9674781571160116268_1472804607
# 19  Organic Search  20160902      3.70E+18  3696906537737368442_1472856874
#
#     socialEngagementType     visitId  visitNumber  visitStartTime  \
# 0   Not Socially Engaged  1472830385            1      1472830385
# 1   Not Socially Engaged  1472880147            1      1472880147
# 2   Not Socially Engaged  1472865386            1      1472865386
# 3   Not Socially Engaged  1472881213            1      1472881213
# 4   Not Socially Engaged  1472822600            2      1472822600
# 5   Not Socially Engaged  1472807194            1      1472807194
# 6   Not Socially Engaged  1472817241            1      1472817241
# 7   Not Socially Engaged  1472812602            1      1472812602
# 8   Not Socially Engaged  1472805784            1      1472805784
# 9   Not Socially Engaged  1472812272            1      1472812272
# 10  Not Socially Engaged  1472834967            1      1472834967
# 11  Not Socially Engaged  1472849434            1      1472849434
# 12  Not Socially Engaged  1472839882            1      1472839882
# 13  Not Socially Engaged  1472803483            1      1472803483
# 14  Not Socially Engaged  1472868337            1      1472868337
# 15  Not Socially Engaged  1472824614            1      1472824614
# 16  Not Socially Engaged  1472801099            1      1472801099
# 17  Not Socially Engaged  1472826820            1      1472826820
# 18  Not Socially Engaged  1472804607            1      1472804607
# 19  Not Socially Engaged  1472856874            1      1472856874
#
#        device.browser          device.browserVersion  ... totals.hits  \
# 0              Chrome  not available in demo dataset  ...           1
# 1             Firefox  not available in demo dataset  ...           1
# 2              Chrome  not available in demo dataset  ...           1
# 3          UC Browser  not available in demo dataset  ...           1
# 4              Chrome  not available in demo dataset  ...           1
# 5              Chrome  not available in demo dataset  ...           1
# 6              Chrome  not available in demo dataset  ...           1
# 7              Chrome  not available in demo dataset  ...           1
# 8   Internet Explorer  not available in demo dataset  ...           1
# 9             Firefox  not available in demo dataset  ...           1
# 10             Chrome  not available in demo dataset  ...           1
# 11             Safari  not available in demo dataset  ...           1
# 12             Safari  not available in demo dataset  ...           1
# 13             Safari  not available in demo dataset  ...           1
# 14             Chrome  not available in demo dataset  ...           1
# 15             Chrome  not available in demo dataset  ...           1
# 16             Chrome  not available in demo dataset  ...           1
# 17  Internet Explorer  not available in demo dataset  ...           1
# 18             Chrome  not available in demo dataset  ...           1
# 19             Chrome  not available in demo dataset  ...           1
#
#    totals.pageviews totals.bounces  totals.newVisits trafficSource.campaign  \
# 0                 1              1                 1              (not set)
# 1                 1              1                 1              (not set)
# 2                 1              1                 1              (not set)
# 3                 1              1                 1              (not set)
# 4                 1              1               NaN              (not set)
# 5                 1              1                 1              (not set)
# 6                 1              1                 1              (not set)
# 7                 1              1                 1              (not set)
# 8                 1              1                 1              (not set)
# 9                 1              1                 1              (not set)
# 10                1              1                 1              (not set)
# 11                1              1                 1              (not set)
# 12                1              1                 1              (not set)
# 13                1              1                 1              (not set)
# 14                1              1                 1              (not set)
# 15                1              1                 1              (not set)
# 16                1              1                 1              (not set)
# 17                1              1                 1              (not set)
# 18                1              1                 1              (not set)
# 19                1              1                 1              (not set)
#
#    trafficSource.source trafficSource.medium trafficSource.keyword  \
# 0                google              organic        (not provided)
# 1                google              organic        (not provided)
# 2                google              organic        (not provided)
# 3                google              organic       google + online
# 4                google              organic        (not provided)
# 5                google              organic        (not provided)
# 6                google              organic        (not provided)
# 7                google              organic        (not provided)
# 8                google              organic        (not provided)
# 9                google              organic        (not provided)
# 10               google              organic        (not provided)
# 11               google              organic        (not provided)
# 12               google              organic        (not provided)
# 13               google              organic        (not provided)
# 14               google              organic        (not provided)
# 15                baidu              organic                   NaN
# 16               google              organic        (not provided)
# 17               google              organic        (not provided)
# 18               google              organic        (not provided)
# 19               google              organic        (not provided)
#
#    trafficSource.adwordsClickInfo.criteriaParameters  \
# 0                      not available in demo dataset
# 1                      not available in demo dataset
# 2                      not available in demo dataset
# 3                      not available in demo dataset
# 4                      not available in demo dataset
# 5                      not available in demo dataset
# 6                      not available in demo dataset
# 7                      not available in demo dataset
# 8                      not available in demo dataset
# 9                      not available in demo dataset
# 10                     not available in demo dataset
# 11                     not available in demo dataset
# 12                     not available in demo dataset
# 13                     not available in demo dataset
# 14                     not available in demo dataset
# 15                     not available in demo dataset
# 16                     not available in demo dataset
# 17                     not available in demo dataset
# 18                     not available in demo dataset
# 19                     not available in demo dataset
#
#    trafficSource.isTrueDirect
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                        True
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9                         NaN
# 10                        NaN
# 11                        NaN
# 12                        NaN
# 13                        NaN
# 14                        NaN
# 15                        NaN
# 16                        NaN
# 17                        NaN
# 18                        NaN
# 19                        NaN
#
# [20 rows x 46 columns]

# %%
#better description for dataset

from scipy import stats


def DataDesc(df):
    print(f"Dataset Shape: {df.shape}")
    summary = pd.DataFrame(df.dtypes,columns=['dtypes'])
    summary = summary.reset_index()
    summary['Name'] = summary['index']
    summary = summary[['Name','dtypes']]
    summary['Missing'] = df.isnull().sum().values    
    summary['Uniques'] = df.nunique().values
    summary['First Value'] = df.loc[0].values
    summary['Second Value'] = df.loc[1].values
    summary['Third Value'] = df.loc[2].values

    for name in summary['Name'].value_counts().index:
        summary.loc[summary['Name'] == name, 'Entropy'] = round(stats.entropy(df[name].value_counts(normalize=True), base=2),2) 
    
    return summary

# %%
DataDesc(train_df)
# Out:
# Dataset Shape: (903653, 55)
#                                                  Name  dtypes  Missing  \
# 0                                     channelGrouping  object        0
# 1                                                date   int64        0
# 2                                       fullVisitorId  object        0
# 3                                           sessionId  object        0
# 4                                socialEngagementType  object        0
# 5                                             visitId   int64        0
# 6                                         visitNumber   int64        0
# 7                                      visitStartTime   int64        0
# 8                                      device.browser  object        0
# 9                               device.browserVersion  object        0
# 10                                 device.browserSize  object        0
# 11                             device.operatingSystem  object        0
# 12                      device.operatingSystemVersion  object        0
# 13                                    device.isMobile    bool        0
# 14                        device.mobileDeviceBranding  object        0
# 15                           device.mobileDeviceModel  object        0
# 16                         device.mobileInputSelector  object        0
# 17                            device.mobileDeviceInfo  object        0
# 18                   device.mobileDeviceMarketingName  object        0
# 19                                device.flashVersion  object        0
# 20                                    device.language  object        0
# 21                                device.screenColors  object        0
# 22                            device.screenResolution  object        0
# 23                              device.deviceCategory  object        0
# 24                               geoNetwork.continent  object        0
# 25                            geoNetwork.subContinent  object        0
# 26                                 geoNetwork.country  object        0
# 27                                  geoNetwork.region  object        0
# 28                                   geoNetwork.metro  object        0
# 29                                    geoNetwork.city  object        0
# 30                                  geoNetwork.cityId  object        0
# 31                           geoNetwork.networkDomain  object        0
# 32                                geoNetwork.latitude  object        0
# 33                               geoNetwork.longitude  object        0
# 34                         geoNetwork.networkLocation  object        0
# 35                                      totals.visits  object        0
# 36                                        totals.hits  object        0
# 37                                   totals.pageviews  object      100
# 38                                     totals.bounces  object   453023
# 39                                   totals.newVisits  object   200593
# 40                          totals.transactionRevenue  object   892138
# 41                             trafficSource.campaign  object        0
# 42                               trafficSource.source  object        0
# 43                               trafficSource.medium  object        0
# 44                              trafficSource.keyword  object   502929
# 45  trafficSource.adwordsClickInfo.criteriaParameters  object        0
# 46                         trafficSource.isTrueDirect  object   629648
# 47                         trafficSource.referralPath  object   572712
# 48                trafficSource.adwordsClickInfo.page  object   882193
# 49                trafficSource.adwordsClickInfo.slot  object   882193
# 50               trafficSource.adwordsClickInfo.gclId  object   882092
# 51       trafficSource.adwordsClickInfo.adNetworkType  object   882193
# 52           trafficSource.adwordsClickInfo.isVideoAd  object   882193
# 53                            trafficSource.adContent  object   892707
# 54                         trafficSource.campaignCode  object   903652
#
#     Uniques                     First Value                   Second Value  \
# 0         8                  Organic Search                 Organic Search
# 1       366                        20160902                       20160902
# 2    714167             1131660440785968503             377306020877927890
# 3    902755  1131660440785968503_1472830385  377306020877927890_1472880147
# 4         1            Not Socially Engaged           Not Socially Engaged
# 5    886303                      1472830385                     1472880147
# 6       384                               1                              1
# 7    887159                      1472830385                     1472880147
# 8        54                          Chrome                        Firefox
# 9         1   not available in demo dataset  not available in demo dataset
# 10        1   not available in demo dataset  not available in demo dataset
# 11       20                         Windows                      Macintosh
# 12        1   not available in demo dataset  not available in demo dataset
# 13        2                           False                          False
# 14        1   not available in demo dataset  not available in demo dataset
# 15        1   not available in demo dataset  not available in demo dataset
# 16        1   not available in demo dataset  not available in demo dataset
# 17        1   not available in demo dataset  not available in demo dataset
# 18        1   not available in demo dataset  not available in demo dataset
# 19        1   not available in demo dataset  not available in demo dataset
# 20        1   not available in demo dataset  not available in demo dataset
# 21        1   not available in demo dataset  not available in demo dataset
# 22        1   not available in demo dataset  not available in demo dataset
# 23        3                         desktop                        desktop
# 24        6                            Asia                        Oceania
# 25       23                    Western Asia                    Australasia
# 26      222                          Turkey                      Australia
# 27      376                           Izmir  not available in demo dataset
# 28       94                       (not set)  not available in demo dataset
# 29      649                           Izmir  not available in demo dataset
# 30        1   not available in demo dataset  not available in demo dataset
# 31    28064                    ttnet.com.tr                    dodo.net.au
# 32        1   not available in demo dataset  not available in demo dataset
# 33        1   not available in demo dataset  not available in demo dataset
# 34        1   not available in demo dataset  not available in demo dataset
# 35        1                               1                              1
# 36      274                               1                              1
# 37      213                               1                              1
# 38        1                               1                              1
# 39        1                               1                              1
# 40     5332                             NaN                            NaN
# 41       10                       (not set)                      (not set)
# 42      380                          google                         google
# 43        7                         organic                        organic
# 44     3659                  (not provided)                 (not provided)
# 45        1   not available in demo dataset  not available in demo dataset
# 46        1                             NaN                            NaN
# 47     1475                             NaN                            NaN
# 48        8                             NaN                            NaN
# 49        2                             NaN                            NaN
# 50    17774                             NaN                            NaN
# 51        2                             NaN                            NaN
# 52        1                             NaN                            NaN
# 53       44                             NaN                            NaN
# 54        1                             NaN                            NaN
#
#                        Third Value  Entropy
# 0                   Organic Search     2.11
# 1                         20160902     8.46
# 2              3895546263509774583    19.18
# 3   3895546263509774583_1472865386    19.78
# 4             Not Socially Engaged     0.00
# 5                       1472865386    19.75
# 6                                1     1.43
# 7                       1472865386    19.75
# 8                           Chrome     1.51
# 9    not available in demo dataset     0.00
# 10   not available in demo dataset     0.00
# 11                         Windows     2.20
# 12   not available in demo dataset     0.00
# 13                           False     0.83
# 14   not available in demo dataset     0.00
# 15   not available in demo dataset     0.00
# 16   not available in demo dataset     0.00
# 17   not available in demo dataset     0.00
# 18   not available in demo dataset     0.00
# 19   not available in demo dataset     0.00
# 20   not available in demo dataset     0.00
# 21   not available in demo dataset     0.00
# 22   not available in demo dataset     0.00
# 23                         desktop     0.98
# 24                          Europe     1.69
# 25                 Southern Europe     3.00
# 26                           Spain     4.33
# 27             Community of Madrid     3.31
# 28                       (not set)     2.06
# 29                          Madrid     3.70
# 30   not available in demo dataset     0.00
# 31                 unknown.unknown     6.87
# 32   not available in demo dataset     0.00
# 33   not available in demo dataset     0.00
# 34   not available in demo dataset     0.00
# 35                               1     0.00
# 36                               1     2.97
# 37                               1     2.81
# 38                               1     0.00
# 39                               1     0.00
# 40                             NaN    11.00
# 41                       (not set)     0.32
# 42                          google     2.41
# 43                         organic     1.78
# 44                  (not provided)     0.91
# 45   not available in demo dataset     0.00
# 46                             NaN     0.00
# 47                             NaN     4.55
# 48                             NaN     0.05
# 49                             NaN     0.16
# 50                             NaN    13.92
# 51                             NaN     0.00
# 52                             NaN     0.00
# 53                             NaN     2.91
# 54                             NaN     0.00

# %%
def fill_na(df):   
    df['totals.pageviews'].fillna(1, inplace=True)
    df['totals.newVisits'].fillna(0, inplace=True)
    df['totals.bounces'].fillna(0, inplace=True) 
    df["totals.transactionRevenue"].fillna(0.0, inplace=True)
    
    # Changing datatypes from object to desired ones
    df['totals.pageviews'] = df['totals.pageviews'].astype(int)
    df['totals.newVisits'] = df['totals.newVisits'].astype(int)
    df['totals.bounces'] = df['totals.bounces'].astype(int)
    df["totals.transactionRevenue"] = df["totals.transactionRevenue"].astype(float)
    
    
    df['trafficSource.isTrueDirect'].fillna(False, inplace=True) 
    df['trafficSource.adwordsClickInfo.isVideoAd'].fillna(True, inplace=True) # filling boolean with True
    df[train_df['geoNetwork.city'] == "(not set)"]['geoNetwork.city'] = np.nan
    df['geoNetwork.city'].fillna("NaN", inplace=True)
    
    return df

df = fill_na(train_df)
#imputation of null values and converting the columns values to int
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()

# %%
#converting to float

df['fullVisitorId'] = df['fullVisitorId'].astype(float)

df['sessionId'] = df['sessionId'].astype(float)



#df1['fullVisitorId'] = df1['fullVisitorId'].astype(float)

#df1['sessionId'] = df1['sessionId'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 903653 entries, 0 to 903652
# Data columns (total 55 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   channelGrouping                                    903653 non-null  object
#  1   date                                               903653 non-null  int64
#  2   fullVisitorId                                      903653 non-null  float64
#  3   sessionId                                          903653 non-null  float64
#  4   socialEngagementType                               903653 non-null  object
#  5   visitId                                            903653 non-null  int64
#  6   visitNumber                                        903653 non-null  int64
#  7   visitStartTime                                     903653 non-null  int64
#  8   device.browser                                     903653 non-null  object
#  9   device.browserVersion                              903653 non-null  object
#  10  device.browserSize                                 903653 non-null  object
#  11  device.operatingSystem                             903653 non-null  object
#  12  device.operatingSystemVersion                      903653 non-null  object
#  13  device.isMobile                                    903653 non-null  bool
#  14  device.mobileDeviceBranding                        903653 non-null  object
#  15  device.mobileDeviceModel                           903653 non-null  object
#  16  device.mobileInputSelector                         903653 non-null  object
#  17  device.mobileDeviceInfo                            903653 non-null  object
#  18  device.mobileDeviceMarketingName                   903653 non-null  object
#  19  device.flashVersion                                903653 non-null  object
#  20  device.language                                    903653 non-null  object
#  21  device.screenColors                                903653 non-null  object
#  22  device.screenResolution                            903653 non-null  object
#  23  device.deviceCategory                              903653 non-null  object
#  24  geoNetwork.continent                               903653 non-null  object
#  25  geoNetwork.subContinent                            903653 non-null  object
#  26  geoNetwork.country                                 903653 non-null  object
#  27  geoNetwork.region                                  903653 non-null  object
#  28  geoNetwork.metro                                   903653 non-null  object
#  29  geoNetwork.city                                    903653 non-null  object
#  30  geoNetwork.cityId                                  903653 non-null  object
#  31  geoNetwork.networkDomain                           903653 non-null  object
#  32  geoNetwork.latitude                                903653 non-null  object
#  33  geoNetwork.longitude                               903653 non-null  object
#  34  geoNetwork.networkLocation                         903653 non-null  object
#  35  totals.visits                                      903653 non-null  object
#  36  totals.hits                                        903653 non-null  object
#  37  totals.pageviews                                   903653 non-null  int64
#  38  totals.bounces                                     903653 non-null  int64
#  39  totals.newVisits                                   903653 non-null  int64
#  40  totals.transactionRevenue                          903653 non-null  float64
#  41  trafficSource.campaign                             903653 non-null  object
#  42  trafficSource.source                               903653 non-null  object
#  43  trafficSource.medium                               903653 non-null  object
#  44  trafficSource.keyword                              400724 non-null  object
#  45  trafficSource.adwordsClickInfo.criteriaParameters  903653 non-null  object
#  46  trafficSource.isTrueDirect                         903653 non-null  bool
#  47  trafficSource.referralPath                         330941 non-null  object
#  48  trafficSource.adwordsClickInfo.page                21460 non-null   object
#  49  trafficSource.adwordsClickInfo.slot                21460 non-null   object
#  50  trafficSource.adwordsClickInfo.gclId               21561 non-null   object
#  51  trafficSource.adwordsClickInfo.adNetworkType       21460 non-null   object
#  52  trafficSource.adwordsClickInfo.isVideoAd           903653 non-null  bool
#  53  trafficSource.adContent                            10946 non-null   object
#  54  trafficSource.campaignCode                         1 non-null       object
# dtypes: bool(3), float64(3), int64(7), object(42)
# memory usage: 361.1+ MB

# %%
for col in df.columns:
    if len(df[col].unique()) == 1:
        df.drop(col,inplace=True,axis=1)

# %%
# This function is to extract date features

from datetime import datetime
def date_process(df):
    df["date"] = pd.to_datetime(df["date"], format="%Y%m%d") # seting the column as pandas datetime
    df["weekday"] = df['date'].dt.weekday #extracting week day
    df["day"] = df['date'].dt.day # extracting day
    df["month"] = df['date'].dt.month # extracting day
    df["year"] = df['date'].dt.year # extracting day
    df['visitHour'] = (df['visitStartTime'].apply(lambda x: str(datetime.fromtimestamp(x).hour))).astype(int)
    
    return df
df = date_process(df)

# %%
df = df.drop(['sessionId', 'trafficSource.campaignCode'], axis = 1)

# %%
df["totals.transactionRevenue"].fillna(0, inplace=True)
train_y = df["totals.transactionRevenue"].values
train_id = df["fullVisitorId"].values

# %%
from sklearn import model_selection, preprocessing, metrics

# label encode the categorical variables 

df_cat = ["channelGrouping", "device.browser", 'device.isMobile',
            "device.deviceCategory", "device.operatingSystem", 
            "geoNetwork.city", "geoNetwork.continent", 
            "geoNetwork.country", "geoNetwork.metro",
            "geoNetwork.networkDomain", "geoNetwork.region", 
            "geoNetwork.subContinent", "trafficSource.adContent", 
            "trafficSource.adwordsClickInfo.adNetworkType", 
            "trafficSource.adwordsClickInfo.gclId", 
            "trafficSource.adwordsClickInfo.page", 
            "trafficSource.adwordsClickInfo.slot", "trafficSource.campaign",
            "trafficSource.keyword", "trafficSource.medium", 
            "trafficSource.referralPath", "trafficSource.source",
            'trafficSource.adwordsClickInfo.isVideoAd', 'trafficSource.isTrueDirect']

# %%
for col in df_cat:
    print(col)
    lbl = preprocessing.LabelEncoder()
    lbl.fit(list(df[col].values.astype('str')))
    df[col] = lbl.transform(list(df[col].values.astype('str')))
# Out:
# channelGrouping
# device.browser
# device.isMobile
# device.deviceCategory
# device.operatingSystem
# geoNetwork.city
# geoNetwork.continent
# geoNetwork.country
# geoNetwork.metro
# geoNetwork.networkDomain
# geoNetwork.region
# geoNetwork.subContinent
# trafficSource.adContent
# trafficSource.adwordsClickInfo.adNetworkType
# trafficSource.adwordsClickInfo.gclId
# trafficSource.adwordsClickInfo.page
# trafficSource.adwordsClickInfo.slot
# trafficSource.campaign
# trafficSource.keyword
# trafficSource.medium
# trafficSource.referralPath
# trafficSource.source
# trafficSource.adwordsClickInfo.isVideoAd
# trafficSource.isTrueDirect

# %%
num_cols = ["totals.hits", "totals.pageviews", "visitNumber", "visitStartTime", 'totals.bounces',  'totals.newVisits']    
for col in num_cols:
    df[col] = df[col].astype(float)

# %%
train_y = np.log1p(df["totals.transactionRevenue"].values)

# %%
train_x = df.drop(['totals.transactionRevenue'], axis = 1)

# %%
train_y = pd.DataFrame(train_y)   
train_y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 903653 entries, 0 to 903652
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       903653 non-null  float64
# dtypes: float64(1)
# memory usage: 6.9 MB

# %%
train_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 903653 entries, 0 to 903652
# Data columns (total 38 columns):
#  #   Column                                        Non-Null Count   Dtype
# ---  ------                                        --------------   -----
#  0   channelGrouping                               903653 non-null  int64
#  1   date                                          903653 non-null  datetime64[ns]
#  2   fullVisitorId                                 903653 non-null  float64
#  3   visitId                                       903653 non-null  int64
#  4   visitNumber                                   903653 non-null  float64
#  5   visitStartTime                                903653 non-null  float64
#  6   device.browser                                903653 non-null  int64
#  7   device.operatingSystem                        903653 non-null  int64
#  8   device.isMobile                               903653 non-null  int64
#  9   device.deviceCategory                         903653 non-null  int64
#  10  geoNetwork.continent                          903653 non-null  int64
#  11  geoNetwork.subContinent                       903653 non-null  int64
#  12  geoNetwork.country                            903653 non-null  int64
#  13  geoNetwork.region                             903653 non-null  int64
#  14  geoNetwork.metro                              903653 non-null  int64
#  15  geoNetwork.city                               903653 non-null  int64
#  16  geoNetwork.networkDomain                      903653 non-null  int64
#  17  totals.hits                                   903653 non-null  float64
#  18  totals.pageviews                              903653 non-null  float64
#  19  totals.bounces                                903653 non-null  float64
#  20  totals.newVisits                              903653 non-null  float64
#  21  trafficSource.campaign                        903653 non-null  int64
#  22  trafficSource.source                          903653 non-null  int64
#  23  trafficSource.medium                          903653 non-null  int64
#  24  trafficSource.keyword                         903653 non-null  int64
#  25  trafficSource.isTrueDirect                    903653 non-null  int64
#  26  trafficSource.referralPath                    903653 non-null  int64
#  27  trafficSource.adwordsClickInfo.page           903653 non-null  int64
#  28  trafficSource.adwordsClickInfo.slot           903653 non-null  int64
#  29  trafficSource.adwordsClickInfo.gclId          903653 non-null  int64
#  30  trafficSource.adwordsClickInfo.adNetworkType  903653 non-null  int64
#  31  trafficSource.adwordsClickInfo.isVideoAd      903653 non-null  int64
#  32  trafficSource.adContent                       903653 non-null  int64
#  33  weekday                                       903653 non-null  int64
#  34  day                                           903653 non-null  int64
#  35  month                                         903653 non-null  int64
#  36  year                                          903653 non-null  int64
#  37  visitHour                                     903653 non-null  int64
# dtypes: datetime64[ns](1), float64(7), int64(30)
# memory usage: 262.0 MB

# %%
X= train_x
Y= train_y

# %%
X['date'].head()
# Out:
# 0   2016-09-02
# 1   2016-09-02
# 2   2016-09-02
# 3   2016-09-02
# 4   2016-09-02
# Name: date, dtype: datetime64[ns]

# %%
df["date"] = pd.to_datetime(df["date"]).dt.date
df['date']
# Out:
# 0         2016-09-02
# 1         2016-09-02
# 2         2016-09-02
# 3         2016-09-02
# 4         2016-09-02
#              ...
# 903648    2017-01-04
# 903649    2017-01-04
# 903650    2017-01-04
# 903651    2017-01-04
# 903652    2017-01-04
# Name: date, Length: 903653, dtype: object

# %%
import datetime

X = df[df['date']<=datetime.date(2017,5,31)]
val_X = df[df['date']>datetime.date(2017,5,31)]
X = X.drop(['date'], axis = 1)
val_X = df.drop(['date'], axis = 1)

# %%
y = np.log1p((X["totals.transactionRevenue"]).values)
val_y = np.log1p((val_X["totals.transactionRevenue"]).values)

# %%
y = pd.DataFrame(y)
val_y = pd.DataFrame(val_y)

# %%
x = X.drop(['totals.transactionRevenue'], axis = 1)
val_x = val_X.drop(['totals.transactionRevenue'], axis = 1)

# %%
print(x.shape,val_x.shape)
print(y.shape,val_y.shape)
# Out:
# (765707, 37) (903653, 37)
# (765707, 1) (903653, 1)

# %%
import xgboost as xg 

from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import r2_score
from sklearn.model_selection import RandomizedSearchCV

# %%
model = xg.XGBRegressor(objective ='reg:squarederror', n_estimators = 1000, verbosity=1, learning_rate=0.3)
model.fit(x, y)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.3, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=1000, n_jobs=4, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=1)

# %%
model.score(x,y)
# Out:
# 0.7815090107586639
